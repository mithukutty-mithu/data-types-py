# %%
#int
k=30
print(type(k)
# Out:
#   Cell In[7], line 3
#     print(type(k)
#                  ^
# _IncompleteInputError: incomplete input

# %%
#int
k=33
print(type(k))
# Out:
# <class 'int'>

# %%
#float
k=float(10)
k
# Out:
# 10.0

# %%
#complx
k1=1+56j
k1
# Out:
# (1+56j)

# %%
a="10"
print(a)
# Out:
# 10

# %%
#str
a="5"
b="10"
c=(a+b)
print(c)
# Out:
# 510

# %%
a=5
b=10
c=(a+b)
print(c)
# Out:
# 15
